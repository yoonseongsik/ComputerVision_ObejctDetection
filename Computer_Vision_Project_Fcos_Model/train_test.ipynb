# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# warehouse train
# !python3 '/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/train.py'\
'--batch_size=8'\
'--lr=5e-2'\
'--max_size=400'\
'--num_workers=2'\
'--num_epoch=10'\
'--num_classes=32'\
"--base_path=/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트"\
"--data=warehouse"\
"--save_path=model_3.pth"\
"--wandb_project_name=CV_project"\
"--wandb_entity_name=jimin_"\
"--wandb_name=train"
# Out:
# 5
# wandb: Currently logged in as: jimin_. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.6
# wandb: Run data is saved locally in /content/wandb/run-20221212_170757-16w0ag1a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train
# wandb: ⭐️ View project at https://wandb.ai/jimin_/CV_project
# wandb: 🚀 View run at https://wandb.ai/jimin_/CV_project/runs/16w0ag1a
# loading annotations into memory...
# Done (t=0.18s)
# creating index...
# index created!
# creating index...
# index created!
# train_dataset length : 3151
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# creating index...
# index created!
# val_dataset length : 156
#
# -----train start-----
# epoch :0
# 100% 394/394 [06:01<00:00,  1.09it/s, loss=1.42, lr=0.05]
#
# -----train start-----
# epoch :1
# 100% 394/394 [06:00<00:00,  1.09it/s, loss=1.45, lr=0.05]
#
# -----train start-----
# epoch :2
# ...

# %%
# warehouse test
# !python3 '/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/test.py'\
'--batch_size=1'\
'--max_size=400'\
'--num_workers=2'\
'--num_classes=32'\
"--base_path=/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트"\
"--data=warehouse_data"\
"--load_path=model_3.pth"\
"--wandb_project_name=CV_project"\
"--wandb_entity_name=jimin_"\
"--wandb_name=test"
# Out:
# wandb: Currently logged in as: jimin_. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.6
# wandb: Run data is saved locally in /content/wandb/run-20221213_060242-2rcfze2m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run test
# wandb: ⭐️ View project at https://wandb.ai/jimin_/CV_project
# wandb: 🚀 View run at https://wandb.ai/jimin_/CV_project/runs/2rcfze2m
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# creating index...
# index created!
# test_dataset length : 161
# -----test start-----
# 100% 161/161 [00:32<00:00,  4.93it/s]
# wandb: Waiting for W&B process to finish... (success).
# wandb: Synced test: https://wandb.ai/jimin_/CV_project/runs/2rcfze2m
# wandb: Synced 5 W&B file(s), 322 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221213_060242-2rcfze2m/logs

# %%
# helmet train
# !python3 './drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/train.py'\
'--batch_size=8'\
'--lr=5e-2'\
'--max_size=400'\
'--num_workers=2'\
'--num_epoch=1'\
'--num_classes=4'\
"--base_path=/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트"\
"--data=helmet"\
"--save_path=model_1.pth"\
"--wandb_project_name=CV_project"\
"--wandb_entity_name=jimin_"\
"--wandb_name=train"
# Out:
# Traceback (most recent call last):
#   File "./drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/train.py", line 10, in <module>
#     from dataset import Helmet_Dataset
#   File "/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/dataset.py", line 5, in <module>
#     import Image
# ModuleNotFoundError: No module named 'Image'

# %%
# helmet test
# !python3 '/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/test.py'\
'--batch_size=1'\
'--max_size=400'\
'--num_workers=2'\
'--num_classes=32'\
"--base_path=/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트"\
"--data=warehouse_data"\
"--load_path=model_2.pth"\
"--wandb_project_name=CV_project"\
"--wandb_entity_name=jimin_"\
"--wandb_name=test"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/KMU/4학년 1학기/시인지/프로젝트/test.py", line 5, in <module>
#     import torch
#   File "/usr/local/lib/python3.8/dist-packages/torch/__init__.py", line 855, in <module>
#     from torch import onnx as onnx
#   File "/usr/local/lib/python3.8/dist-packages/torch/onnx/__init__.py", line 12, in <module>
#     from . import (  # usort:skip. Keep the order instead of sorting lexicographically
#   File "/usr/local/lib/python3.8/dist-packages/torch/onnx/symbolic_caffe2.py", line 4, in <module>
#     from torch.onnx import symbolic_helper, symbolic_opset9 as opset9
#   File "/usr/local/lib/python3.8/dist-packages/torch/onnx/symbolic_helper.py", line 17, in <module>
#     from torch.onnx import (  # noqa: F401
#   File "/usr/local/lib/python3.8/dist-packages/torch/onnx/_patch_torch.py", line 11, in <module>
#     from torch.onnx import _deprecation, utils
# ...
